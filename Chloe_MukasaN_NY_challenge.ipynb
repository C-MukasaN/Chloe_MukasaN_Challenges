# %%
# import file : 

import pandas as pd
import numpy as np
data="2018_Central_Park_Squirrel_Census_-_Squirrel_Data.csv"
df = pd.read_csv(data)
df.head()
# Out:
#            X          Y Unique Squirrel ID Hectare Shift      Date  \
# 0 -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1 -73.957044  40.794851     37E-PM-1006-03     37E    PM  10062018
# 2 -73.976831  40.766718      2E-AM-1010-03     02E    AM  10102018
# 3 -73.975725  40.769703      5D-PM-1018-05     05D    PM  10182018
# 4 -73.959313  40.797533     39B-AM-1018-01     39B    AM  10182018
#
#    Hectare Squirrel Number       Age Primary Fur Color Highlight Fur Color  \
# 0                        3       NaN               NaN                 NaN
# 1                        3     Adult              Gray            Cinnamon
# 2                        3     Adult          Cinnamon                 NaN
# 3                        5  Juvenile              Gray                 NaN
# 4                        1       NaN               NaN                 NaN
#
#    ...   Kuks  Quaas  Moans Tail flags Tail twitches  Approaches  Indifferent  \
# ...

# %%
# number of files :

df.shape
# Out:
# (3023, 31)

# %%
# total of missing values :

df.isnull().sum()
# Out:
# X                                                0
# Y                                                0
# Unique Squirrel ID                               0
# Hectare                                          0
# Shift                                            0
# Date                                             0
# Hectare Squirrel Number                          0
# Age                                            121
# Primary Fur Color                               55
# Highlight Fur Color                           1086
# Combination of Primary and Highlight Color       0
# Color notes                                   2841
# Location                                        64
# Above Ground Sighter Measurement               114
# Specific Location                             2547
# Running                                          0
# Chasing                                          0
# Climbing                                         0
# ...

# %%
# count the number of nan in each column :

s = df.isnull().apply(sum, axis=0)

# delete columns that have more than 50 missing values : 

for col in df: 
   if s[col] >= 50:  
       del df[col]
print(df.shape)
df.head()
# Out:
# (3023, 22)
#            X          Y Unique Squirrel ID Hectare Shift      Date  \
# 0 -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1 -73.957044  40.794851     37E-PM-1006-03     37E    PM  10062018
# 2 -73.976831  40.766718      2E-AM-1010-03     02E    AM  10102018
# 3 -73.975725  40.769703      5D-PM-1018-05     05D    PM  10182018
# 4 -73.959313  40.797533     39B-AM-1018-01     39B    AM  10182018
#
#    Hectare Squirrel Number Combination of Primary and Highlight Color  \
# 0                        3                                          +
# 1                        3                              Gray+Cinnamon
# 2                        3                                  Cinnamon+
# 3                        5                                      Gray+
# 4                        1                                          +
#
#    Running  Chasing  ...  Foraging   Kuks  Quaas  Moans  Tail flags  \
# ...

# %%
df = df.drop(['Lat/Long'], axis=1) # delete the "Lat/Long" column => already x and y, easier to use

# %%
print(df.shape)
df.head()
# Out:
# (3023, 21)
#            X          Y Unique Squirrel ID Hectare Shift      Date  \
# 0 -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1 -73.957044  40.794851     37E-PM-1006-03     37E    PM  10062018
# 2 -73.976831  40.766718      2E-AM-1010-03     02E    AM  10102018
# 3 -73.975725  40.769703      5D-PM-1018-05     05D    PM  10182018
# 4 -73.959313  40.797533     39B-AM-1018-01     39B    AM  10182018
#
#    Hectare Squirrel Number Combination of Primary and Highlight Color  \
# 0                        3                                          +
# 1                        3                              Gray+Cinnamon
# 2                        3                                  Cinnamon+
# 3                        5                                      Gray+
# 4                        1                                          +
#
#    Running  Chasing  ...  Eating  Foraging   Kuks  Quaas  Moans  Tail flags  \
# ...

# %%
# save into a .csv file :

smaller_df = df.to_csv('smaller_df.csv', index = False)

# %% [markdown]
# # Columns :

# %% [markdown]
# # Dealing with missing values :

# %%
#liste of missing values :

missing_values = ["","+","na","n/a","nan"," "]
smaller_df = pd.read_csv("smaller_df.csv", na_values=missing_values)

smaller_df.isnull().sum()
# Out:
# X                                              0
# Y                                              0
# Unique Squirrel ID                             0
# Hectare                                        0
# Shift                                          0
# Date                                           0
# Hectare Squirrel Number                        0
# Combination of Primary and Highlight Color    55
# Running                                        0
# Chasing                                        0
# Climbing                                       0
# Eating                                         0
# Foraging                                       0
# Kuks                                           0
# Quaas                                          0
# Moans                                          0
# Tail flags                                     0
# Tail twitches                                  0
# Approaches                                     0
# ...

# %%
# showing the Combinaison column :

smaller_df["Combination of Primary and Highlight Color"].unique()
# Out:
# array([nan, 'Gray+Cinnamon', 'Cinnamon+', 'Gray+', 'Cinnamon+White',
#        'Gray+White', 'Cinnamon+Gray', 'Gray+Cinnamon, White',
#        'Cinnamon+Gray, White', 'Gray+Black, Cinnamon, White', 'Black+',
#        'Gray+Black', 'Black+White', 'Black+Cinnamon', 'Gray+Black, White',
#        'Cinnamon+Black', 'Black+Gray', 'Gray+Black, Cinnamon',
#        'Black+Cinnamon, White', 'Cinnamon+Black, White',
#        'Black+Gray, White', 'Cinnamon+Gray, Black'], dtype=object)

# %% [markdown]
# # Dealing with rows :

# %%
# showing all the uniques values for check :

for elements in smaller_df:
    print("      ##########",elements,"##########")
    print(smaller_df[elements].unique())
# Out:
#       ########## X ##########
# [-73.95613449 -73.95704377 -73.97683118 ... -73.9665872  -73.96399412
#  -73.97547942]
#       ########## Y ##########
# [40.79408239 40.79485094 40.76671781 ... 40.78367751 40.78991523
#  40.76964045]
#       ########## Unique Squirrel ID ##########
# ['37F-PM-1014-03' '37E-PM-1006-03' '2E-AM-1010-03' ... '22D-PM-1012-07'
#  '29B-PM-1010-02' '5E-PM-1012-01']
#       ########## Hectare ##########
# ['37F' '37E' '02E' '05D' '39B' '33H' '06G' '35C' '07B' '32E' '13E' '11H'
#  '36H' '33F' '21C' '11D' '20B' '36I' '05C' '07H' '16C' '14E' '32A' '17F'
#  '16I' '12I' '32F' '25A' '15E' '39G' '29I' '07E' '17C' '10A' '28A' '22F'
#  '12B' '18A' '29C' '38C' '31H' '08H' '34F' '13H' '17E' '02B' '19D' '40B'
#  '03E' '39C' '14F' '06I' '15F' '08B' '03A' '05E' '05F' '11B' '16E' '13F'
#  '29H' '23C' '33C' '38G' '16G' '35A' '28C' '32D' '22A' '19C' '15G' '10F'
#  '42E' '22B' '05A' '32H' '42C' '41D' '21G' '07F' '38F' '41B' '36A' '31A'
# ...

# %%
# delete rows with missing values :

cleaned_df = smaller_df.dropna()
print(cleaned_df.shape)
cleaned_df
# Out:
# (2968, 21)
#               X          Y Unique Squirrel ID Hectare Shift      Date  \
# 1    -73.957044  40.794851     37E-PM-1006-03     37E    PM  10062018
# 2    -73.976831  40.766718      2E-AM-1010-03     02E    AM  10102018
# 3    -73.975725  40.769703      5D-PM-1018-05     05D    PM  10182018
# 5    -73.956570  40.790256     33H-AM-1019-02     33H    AM  10192018
# 6    -73.971974  40.769305      6G-PM-1020-02     06G    PM  10202018
# ...         ...        ...                ...     ...   ...       ...
# 3018 -73.963943  40.790868     30B-AM-1007-04     30B    AM  10072018
# 3019 -73.970402  40.782560     19A-PM-1013-05     19A    PM  10132018
# 3020 -73.966587  40.783678     22D-PM-1012-07     22D    PM  10122018
# 3021 -73.963994  40.789915     29B-PM-1010-02     29B    PM  10102018
# 3022 -73.975479  40.769640      5E-PM-1012-01     05E    PM  10122018
#
#       Hectare Squirrel Number Combination of Primary and Highlight Color  \
# ...

# %%
cleaned_df.shape
# Out:
# (3023, 21)

# %%
# save into a .csv file :

clean_df = cleaned_df.to_csv('clean_df.csv', index = False)
